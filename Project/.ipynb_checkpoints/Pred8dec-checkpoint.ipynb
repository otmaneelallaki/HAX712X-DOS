# %% [markdown]
# # Main Code

# %% [markdown]
# # packages Importation

# %%
from Prediction import ClassModel as md
from Prediction import DataCollection as dc
import pandas as pd

# %%
data = dc.Data()
data.impo()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/n7/c4pg58mj1z558vm92vdfcf140000gn/T/ipykernel_15244/3714561797.py in <module>
#       1 data = dc.Data()
# ----> 2 data.impo()
#
# ~/Desktop/HAX712X-DOS/Project/Prediction/DataCollection.py in impo(self)
#      25         :rtype: DataFrame
#      26         """
# ---> 27         self.data = pd.read_csv("./Prediction/Dataset/DataTrining.csv")
#      28         return
#      29
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
data = pd.read_csv("/Users/mac/Desktop/HAX712X-DOS/Project/Prediction/DataSet.csv")

# %%
data.drop(["Gaz (MW)","Nucléaire (MW)" ], axis = 1, inplace = True)
data.rename(columns={'Consommation (MW)': 'target'}, inplace=True)

# %%
data.set_index("Time", inplace=True)

# %%
data.index = pd.to_datetime(data.index)

# %%
Object = md.Dos(data)
Featurs = Object.createFeatures()

# %%
reg = Object.fitModel()
# Out:
# [18:19:47] WARNING: /Users/runner/work/xgboost/xgboost/python-package/build/temp.macosx-10.9-x86_64-cpython-38/xgboost/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:52778.54847
# [100]	validation_0-rmse:19801.87166
# [200]	validation_0-rmse:8266.22132
# [300]	validation_0-rmse:4801.38859
# [400]	validation_0-rmse:4012.81692
# [499]	validation_0-rmse:3825.82985

# %%
dayPred, date = Object.DayPred(2022,12,8,reg)
dayPred
# Out:
#           Date  Heure  Consommation (MW)
# 0   2022-12-08  00:00       62485.835938
# 1   2022-12-08  00:15       62046.429688
# 2   2022-12-08  00:30       59981.953125
# 3   2022-12-08  00:45       58877.906250
# 4   2022-12-08  01:00       58543.164062
# ..         ...    ...                ...
# 91  2022-12-08  22:45       64845.078125
# 92  2022-12-08  23:00       64616.890625
# 93  2022-12-08  23:15       64469.445312
# 94  2022-12-08  23:30       64469.445312
# 95  2022-12-08  23:45       64390.421875
#
# [96 rows x 3 columns]

# %%
Object.plot(dayPred, date)
